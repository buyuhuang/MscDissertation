# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-4d9fe834df15> in <module>()
#      20         # if it has a geometry attribute (a list of line segments), add them
#      21         # to the list of lines to plot
# ---> 22         xs, ys = data['geometry'].xy
#      23         zs = G.node[u]['z']
#      24         lines.append(list(zip(xs, ys, zs)))
#
# AttributeError: 'str' object has no attribute 'xy'

# %%
mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot(x, y, z, label='parametric curve')
ax.legend()

plt.show()
